# %% [markdown]
# # APS106 - Fundamentals of Computer Programming
# ## Week 6 | Lecture 1 (6.1) - Jeopardy Review

# %%
import utils2 as utils

# %% [markdown]
# # Final Jeopardy value is 4751!!!

# %%
final_value = 4751

scores = {
    'mechanical': sum([-1000, 1000, 1000, 750, 500, 750, 250, 250]) , #  sum([1000]),
    'chem': sum([500]) , # sum([250, 250,-1000, -250, -250, -250, -750, 750, -1000, 3500, 500]),
    'civil': sum([-750, -500]) , # sum([-1000, 500, -250, 500, -750, 1000]),
    'mineral': sum([1000, 500, 250, 250]) , # sum([0]),
    'materials':sum([-1000, 500, 1000, 750, -750]) , # sum([0]),
    'industrial':sum([]) , # sum([1000, 250, -250, 250, -750]),
    'track1': sum([]) , #sum([0])
}

utils.plot_scores(scores)

# %%
def check_command(command_string):
    '''
    str -> str
    '''

    if command_string.startswith('CMD'):
        i = 0
        count = 0
        while i < len(command_string):
            if command_string[i] in "0123456789":
                count += 1
            i += 1
        result = 'valid:' + str(count)

    else:
        result = 'invalid'
    return result

# %%
check_command('CMD12345')
# Out:
# 'valid:5'

# %%
check_command('CMB12345')
# Out:
# 'invalid'
